# %%
import pytesseract
from PIL import Image

# %%
image_path = "F:/Fork Projects/My-UTS-Repo/32040 - Industry Project/MultiModal-Video-Summarization/Concept_draft.png"
# image_path = "../video summarization/video_frames/frame_2910.jpg"
img = Image.open(image_path)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2111x1811>

# %%
pytesseract.pytesseract.tesseract_cmd = r"D:/Program Files/Tesseract-OCR/tesseract.exe"

# %%
text = pytesseract.image_to_string(img)

print(text)
# Out:
# Input Video URL
#
# Video Processing |
#
# | Audio Processing
#
# —
#
# Extract spatiotemporal
# features from Video frames
#
# Detect transitions and group
# scenes based on context
#
# Generate descriptions for
# keyframes
#
# Identify and label objects on
# screen like slides, graphs,
# diagrams, etc. Understand
#
# context of segmented scene
#
# Extract text from slides and
# written content in the frames
#
# —| vivit
# + TimeSformer
# —| Scene Boundary
# Scene Transition
# Extraction
# Scene
# *|  Segmenation/Grouping
# —| BLIP
# Visual Description
# Generation
# +] ClipCap
# —| YOLOv5
# Semantic Analysis |<
# + DeepLabv3
# —| Tesseract OCR
# +] Google Cloud Vision API
#
# |
#
# ‘Speech-to-Text
#
# Transcribe to audio speech to
# text
#
# Divide the transcript into
# segments based on topic
#
# BART
#
# GPT
#
# Longformer
#
# BigBird
#
# Overall Summary Output
#
# Context point and Timestamps.
